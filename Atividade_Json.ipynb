# %% [markdown]
# <a href="https://colab.research.google.com/github/kennedy1907big/estrutura-de-dados/blob/main/Atividade_Json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
dados = {
    "nome": "Kennedy",
    "idade": 25,
    "cidade": "Tres Lagoas"
}

json_str = json.dumps(dados)
print(json_str)
# Out:
# {"nome": "Kennedy", "idade": 25, "cidade": "Tres Lagoas"}

# %%
print(json.dumps(dados, indent=4))
# Out:
# {
#     "nome": "Kennedy",
#     "idade": 25,
#     "cidade": "Tres Lagoas"
# }

# %%
json_texto = '{"nome": "Kennedy", "idade": 25}'
dicionario = json.loads(json_texto)

print(dicionario)
print(type(dicionario))
# Out:
# {'nome': 'Kennedy', 'idade': 25}
# <class 'dict'>

# %%
json_manual = '{"produto": "Coca", "preco": 5.50}'
dados = json.loads(json_manual)

print(dados)
# Out:
# {'produto': 'Coca', 'preco': 5.5}

# %%
with open("dados.json", "w") as arquivo:
    json.dump(dados, arquivo)

# %%
with open("dados.json", "r") as arquivo:
    conteudo = json.load(arquivo)

print(conteudo)
# Out:
# {'produto': 'Coca', 'preco': 5.5}

# %%
numeros = [1, 2, 3, 4, 5]
json_lista = json.dumps(numeros)

print(json_lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
dados = json.loads(json_lista)

print(type(dados))
# Out:
# <class 'list'>

# %%
json_exemplo = '{"ativo": true, "erro": false, "valor": null}'
dados = json.loads(json_exemplo)

print(dados)
# Out:
# {'ativo': True, 'erro': False, 'valor': None}

# %%
dados = {
    "numeros": {1, 2, 3}  # set
}

json.dumps(dados)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4260/1212714719.py in <cell line: 0>()
#       3 }
#       4
# ----> 5 json.dumps(dados)
#
# /usr/lib/python3.12/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# /usr/lib/python3.12/json/encoder.py in encode(self, o)
#     198         # exceptions aren't as detailed.  The list call should be roughly
#     199         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200         chunks = self.iterencode(o, _one_shot=True)
# ...

# %% [markdown]
# o valor {1, 2, 3} é um conjunto (set) e o JSON não tem represnetação equivalente para isso, ou seja, antes tem tem que converter o conjunto para ista antes de serializar, abaixo esta a forma corrigida se precisar

# %%
dados = {
    "numeros": list({1, 2, 3})
}
json.dumps(dados)

# %%
aluno = {
    "nome": "Ana",
    "nota": 8.5,
    "aprovado": True
}

print(json.dumps(aluno, indent=4))

# %%
print(json.dumps(aluno, indent=4, ensure_ascii=False))

# %%
nomes = ["Ana", "João", "Carlos"]
json_nomes = json.dumps(nomes)

dados = json.loads(json_nomes)

for nome in dados:
    print(nome)
# Out:
# Ana
# João
# Carlos

# %%
json_num = '[10, 20, 30]'
dados = json.loads(json_num)

print(sum(dados))
# Out:
# 60

# %%
import json

# Criando o arquivo
dados = {
    "nome": "Teste",
    "idade": 30
}

with open("teste.json", "w") as f:
    json.dump(dados, f)

# Leitura
with open("teste.json") as f:
    print(json.load(f))
# Out:
# {'nome': 'Teste', 'idade': 30}

# %%
with open("teste.json") as f:
    print(json.load(f))
# Out:
# {'nome': 'Teste', 'idade': 30}

# %%
dados = json.loads(json_texto)

print(dados["nome"])
# Out:
# Kennedy

# %%
dados = {
    "nome": "Carlos",
    "idade": 40,
    "cidade": "SP"
}

for chave, valor in dados.items():
    print(chave, ":", valor)
# Out:
# nome : Carlos
# idade : 40
# cidade : SP

# %%
dados = {
    "nomes": ["Ana", "João"]
}

print(json.dumps(dados))
# Out:
# {"nomes": ["Ana", "Jo\u00e3o"]}

# %%
json_obj = '''
[
    {"nome": "Ana"},
    {"nome": "João"}
]
'''

dados = json.loads(json_obj)

for pessoa in dados:
    print(pessoa["nome"])
# Out:
# Ana
# João

# %%
banco = [
    {"id": 1, "nome": "Kennedy", "saldo": 1000},
    {"id": 2, "nome": "Ana", "saldo": 1500}
]

with open("banco.json", "w") as f:
    json.dump(banco, f, indent=4)

print("Banco criado!")
# Out:
# Banco criado!

# %%
alunos = [
    {"nome": "Maria", "nota": 9.0},
    {"nome": "João", "nota": 7.5},
    {"nome": "Ana", "nota": 5.0}
]

for aluno in alunos:
    print(aluno["nome"], "-", aluno["nota"])
# Out:
# Maria - 9.0
# João - 7.5
# Ana - 5.0

# %%
for aluno in alunos:
    if aluno["nota"] >= 7:
        print(aluno)
# Out:
# {'nome': 'Maria', 'nota': 9.0}
# {'nome': 'João', 'nota': 7.5}

# %%
nome_busca = "Ana"

for aluno in alunos:
    if aluno["nome"] == nome_busca:
        print(aluno)
# Out:
# {'nome': 'Ana', 'nota': 5.0}

# %%
for aluno in alunos:
    if aluno["nome"] == "João":
        aluno["nota"] = 7

# %%
alunos.append({"nome": "Lucas", "nota": 10})

# %%
nome_remover = "Ana"

alunos = [a for a in alunos if a["nome"] != nome_remover]

# %%
media = sum(a["nota"] for a in alunos) / len(alunos)
print(media)
# Out:
# 8.666666666666666

# %%
maior = max(alunos, key=lambda a: a["nota"])
print(maior)
# Out:
# {'nome': 'Lucas', 'nota': 10}

# %%
ordenados = sorted(alunos, key=lambda a: a["nota"])
print(ordenados)
# Out:
# [{'nome': 'João', 'nota': 7}, {'nome': 'Maria', 'nota': 9.0}, {'nome': 'Lucas', 'nota': 10}]

# %%
import json

tuplas = [("Ana", 8), ("João", 6)]

json_str = json.dumps(tuplas)
print(json_str)
# Out:
# [["Ana", 8], ["Jo\u00e3o", 6]]

# %%
dados = json.loads(json_str)

tuplas = [tuple(item) for item in dados]
print(tuplas)
# Out:
# [('Ana', 8), ('João', 6)]

# %%
produtos = [
    {"nome": "Mouse", "preco": 50, "quantidade": 10},
    {"nome": "Teclado", "preco": 100, "quantidade": 5}
]

# %%
print(json.dumps(produtos, indent=4))
# Out:
# [
#     {
#         "nome": "Mouse",
#         "preco": 50,
#         "quantidade": 10
#     },
#     {
#         "nome": "Teclado",
#         "preco": 100,
#         "quantidade": 5
#     }
# ]

# %%
total = sum(p["preco"] * p["quantidade"] for p in produtos)
print(total)
# Out:
# 1000

# %%
for p in produtos:
    if p["quantidade"] < 6:
        print(p)
# Out:
# {'nome': 'Teclado', 'preco': 100, 'quantidade': 5}

# %%
for p in produtos:
    if p["nome"] == "Mouse":
        p["preco"] = 60

# %%
empresa = {
    "nome": "Tech",
    "funcionarios": [
        {"nome": "Ana", "cargo": "Dev"}
    ]
}

# %%
print(empresa["funcionarios"][0]["nome"])
# Out:
# Ana

# %%
print(empresa.get("funcionarios", [{}])[0].get("nome"))
# Out:
# Ana

# %%
for f in empresa["funcionarios"]:
    print("Nome:", f["nome"])
    print("Cargo:", f["cargo"])
# Out:
# Nome: Ana
# Cargo: Dev

# %%
with open("alunos.json", "w") as f:
    json.dump(alunos, f, indent=4)

# %%
import json
from collections import Counter

usuarios = [
    {
        "nome": "Ana",
        "contatos": {
            "email": "ana@email.com",
            "telefone": "1111"
        }
    },
    {
        "nome": "João",
        "contatos": {
            "email": "joao@email.com",
            "telefone": "2222"
        }
    }
]

# %%
print(usuarios[0]["contatos"]["email"])
# Out:
# ana@email.com

# %%
flatten = []

for u in usuarios:
    novo = {
        "nome": u["nome"],
        "email": u["contatos"]["email"],
        "telefone": u["contatos"]["telefone"]
    }
    flatten.append(novo)

print(flatten)
# Out:
# [{'nome': 'Ana', 'email': 'ana@email.com', 'telefone': '1111'}, {'nome': 'João', 'email': 'joao@email.com', 'telefone': '2222'}]

# %%
alunos = [
    {"nome": "Ana", "turma": "A"},
    {"nome": "João", "turma": "B"},
    {"nome": "Carlos", "turma": "A"}
]

grupo = {}

for a in alunos:
    turma = a["turma"]
    grupo.setdefault(turma, []).append(a)

print(grupo)
# Out:
# {'A': [{'nome': 'Ana', 'turma': 'A'}, {'nome': 'Carlos', 'turma': 'A'}], 'B': [{'nome': 'João', 'turma': 'B'}]}

# %%
nomes = [a["nome"] for a in alunos]

contagem = Counter(nomes)
print(contagem)
# Out:
# Counter({'Ana': 1, 'João': 1, 'Carlos': 1})

# %%
vendas = [
    {"vendedor": "Ana", "valor": 100},
    {"vendedor": "Ana", "valor": 200},
    {"vendedor": "João", "valor": 150}
]

total = {}

for v in vendas:
    total[v["vendedor"]] = total.get(v["vendedor"], 0) + v["valor"]

print(total)
# Out:
# {'Ana': 300, 'João': 150}

# %%
valores = [10, 50, 30, 80, 20]

top3 = sorted(valores, reverse=True)[:3]
print(top3)
# Out:
# [80, 50, 30]

# %%
json1 = {"nome": "Ana"}
json2 = {"idade": 25}

mesclado = {**json1, **json2}
print(mesclado)
# Out:
# {'nome': 'Ana', 'idade': 25}

# %%
resultado = [
    a for a in alunos
    if a["turma"] == "A" and a["nome"].startswith("A")
]

print(resultado)
# Out:
# [{'nome': 'Ana', 'turma': 'A'}]

# %%
ordenado = sorted(alunos, key=lambda x: (x["turma"], x["nome"]))
print(ordenado)
# Out:
# [{'nome': 'Ana', 'turma': 'A'}, {'nome': 'Carlos', 'turma': 'A'}, {'nome': 'João', 'turma': 'B'}]

# %%
def paginar(lista, pagina, tamanho):
    inicio = (pagina - 1) * tamanho
    fim = inicio + tamanho
    return lista[inicio:fim]

print(paginar(alunos, 1, 2))
# Out:
# [{'nome': 'Ana', 'turma': 'A'}, {'nome': 'João', 'turma': 'B'}]

# %%
notas = [7, 8, 9, 6]

media = sum(notas) / len(notas)
print("Média:", media)
print("Maior:", max(notas))
print("Menor:", min(notas))
# Out:
# Média: 7.5
# Maior: 9
# Menor: 6

# %%
dados = {"nome": "Ana", "idade": 25}

json_manual = '{' + f'"nome": "{dados["nome"]}", "idade": {dados["idade"]}' + '}'
print(json_manual)
# Out:
# {"nome": "Ana", "idade": 25}

# %%
texto = '{"nome": "Ana"}'

try:
    json.loads(texto)
    print("JSON válido")
except:
    print("JSON inválido")
# Out:
# JSON válido

# %%
for a in alunos:
    if "nome" not in a:
        print("Faltando nome")

# %%
dados = {"nome": None}

if dados["nome"] is None:
    dados["nome"] = "Desconhecido"

print(dados)
# Out:
# {'nome': 'Desconhecido'}

# %%
dados = {"nome": "ANA"}

dados["nome"] = dados["nome"].lower()
print(dados)
# Out:
# {'nome': 'ana'}

# %%
nome = input("Nome: ")
idade = int(input("Idade: "))

dados = {"nome": nome, "idade": idade}

print(json.dumps(dados))
# Out:
# Nome: kenney
# Idade: 19
# {"nome": "kenney", "idade": 19}

# %%
cache = {}

def buscar(id):
    if id in cache:
        return cache[id]

    resultado = {"id": id, "dados": "API"}
    cache[id] = resultado
    return resultado

print(buscar(1))
print(buscar(1))
# Out:
# {'id': 1, 'dados': 'API'}
# {'id': 1, 'dados': 'API'}

# %%
a = {"nome": "Ana", "idade": 25}
b = {"nome": "Ana", "idade": 30}

for chave in a:
    if a[chave] != b.get(chave):
        print(f"{chave} diferente: {a[chave]} != {b.get(chave)}")
# Out:
# idade diferente: 25 != 30
